# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('Avacado.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1512          10  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   int64
#  12  region        1517 non-null   object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 154.2+ KB

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#For the Average price
df.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.18, 1.29, 1.25, 1.03, 1.39,
#        1.4 , 1.36, 1.3 , 0.88, 1.21, 0.9 , 0.94, 0.75, 0.77, 0.81, 0.8 ,
#        0.72, 0.79, 0.67, 0.82, 0.68, 0.76, 0.91, 1.38, 0.92, 0.78, 0.74,
#        0.62, 0.83, 0.87, 0.73, 0.7 , 0.89, 0.85, 1.44, 1.42, 1.41, 0.49,
#        0.53, 0.66, 0.56, 0.6 , 0.71, 0.65, 0.58, 0.54, 0.52, 0.51, 0.57,
#        0.63, 0.64, 0.61, 0.84, 0.86, 0.69, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.51, 1.61, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.68,
#        1.54, 1.64, 1.58])

# %%
df.AveragePrice.value_counts()
# Out:
# 1.08    46
# 0.99    44
# 1.03    44
# 1.10    43
# 1.09    43
#         ..
# 0.51     1
# 0.52     1
# 0.54     1
# 1.42     1
# 1.58     1
# Name: AveragePrice, Length: 113, dtype: int64

# %%
#To check missing items
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# ...

# %%
dfcor=df.corr()

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (1517, 13)

# %%
df['AveragePrice'].mean()
# Out:
# 1.0749901120632825

# %%
#Minimum price of avacado
df['AveragePrice'].min()
# Out:
# 0.49

# %%
#Maximum price of avacado
df['AveragePrice'].max()
# Out:
# 1.68

# %%
#Max numbers of avacado sold
df['Total Volume'].max()
# Out:
# 44655461.51

# %%
#Number of people purchased avacado
df['type'].value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
df[['Total Volume','Total Bags']].corr()
# Out:
#               Total Volume  Total Bags
# Total Volume      1.000000    0.967689
# Total Bags        0.967689    1.000000

# %%
df.groupby('region')['AveragePrice'].mean()
# Out:
# region
# Albany                 1.238657
# Atlanta                1.012037
# BaltimoreWashington    1.160923
# Boise                  0.974923
# Boston                 1.205484
# BuffaloRochester       1.301569
# California             1.055921
# Charlotte              1.311613
# Chicago                1.214783
# Columbus               1.012553
# DallasFtWorth          0.755882
# Denver                 1.080833
# Detroit                1.041250
# GrandRapids            1.136957
# GreatLakes             1.107222
# HarrisburgScranton     1.157368
# HartfordSpringfield    1.209231
# Houston                0.780690
# Indianapolis           1.126250
# Jacksonville           1.113659
# LasVegas               1.041000
# LosAngeles             0.863333
# Louisville             1.042941
# MiamiFtLauderdale      1.176471
# Midsouth               1.081111
# Nashville              1.028400
# NewYork                1.248636
# Northeast              1.236667
# NorthernNewEngland     1.111034
# ...

# %%
df.groupby('year')['Total Volume'].mean()
# Out:
# year
# 2015    1.610065e+06
# 2016    1.559787e+06
# Name: Total Volume, dtype: float64

# %%
conventional= df[df['type']=='conventional']

# %%
conventional
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     27-12-2015          1.33      64236.62   1036.74   54454.85     48.16
# 1     20-12-2015          1.35      54876.98    674.28   44638.81     58.33
# 2     13-12-2015          0.93     118220.22    794.70  109149.67    130.50
# 3     06-12-2015          1.08      78992.15   1132.00   71976.41     72.58
# 4     29-11-2015          1.28      51039.60    941.48   43838.39     75.78
# ...          ...           ...           ...       ...        ...       ...
# 1512  16-10-2016          1.39     190846.01  57529.11   56366.66  17531.78
# 1513  09-10-2016          1.51     178235.75  43325.87   52189.61  19419.57
# 1514  02-10-2016          1.48     178410.82  46364.75   52893.38  16736.92
# 1515  25-09-2016          1.47     189131.52  54110.79   53593.58  17495.42
# 1516  18-09-2016          1.43     182978.30  43116.41   54193.42  16563.91
#
# ...

# %%
#Finding sales by region
df.groupby('region')['Total Volume'].mean()
# Out:
# region
# Albany                 7.629020e+04
# Atlanta                4.676372e+05
# BaltimoreWashington    8.076442e+05
# Boise                  8.104617e+04
# Boston                 5.534586e+05
# BuffaloRochester       1.321844e+05
# California             6.035277e+06
# Charlotte              1.762782e+05
# Chicago                8.118822e+05
# Columbus               1.457604e+05
# DallasFtWorth          1.195363e+06
# Denver                 7.176015e+05
# Detroit                3.390654e+05
# GrandRapids            1.908866e+05
# GreatLakes             3.276358e+06
# HarrisburgScranton     2.183198e+05
# HartfordSpringfield    2.685772e+05
# Houston                1.115564e+06
# Indianapolis           1.575043e+05
# Jacksonville           1.380222e+05
# LasVegas               2.790102e+05
# LosAngeles             2.732180e+06
# Louisville             7.764284e+04
# MiamiFtLauderdale      4.713218e+05
# Midsouth               2.355099e+06
# Nashville              1.674714e+05
# ...

# %%
#Finding correlation 
df[['4046','4770','4225','XLarge Bags','Large Bags','Small Bags','Total Volume','Total Bags']].corr()
# Out:
#                   4046      4770      4225  XLarge Bags  Large Bags  \
# 4046          1.000000  0.898570  0.951952     0.474063    0.884229
# 4770          0.898570  1.000000  0.927757     0.646053    0.840523
# 4225          0.951952  0.927757  1.000000     0.504718    0.900496
# XLarge Bags   0.474063  0.646053  0.504718     1.000000    0.447779
# Large Bags    0.884229  0.840523  0.900496     0.447779    1.000000
# Small Bags    0.922278  0.923607  0.943988     0.611300    0.879131
# Total Volume  0.985568  0.934347  0.987154     0.521717    0.910226
# Total Bags    0.930395  0.926405  0.951779     0.601856    0.911336
#
#               Small Bags  Total Volume  Total Bags
# 4046            0.922278      0.985568    0.930395
# 4770            0.923607      0.934347    0.926405
# 4225            0.943988      0.987154    0.951779
# XLarge Bags     0.611300      0.521717    0.601856
# Large Bags      0.879131      0.910226    0.911336
# ...

# %%
df['Month']=df['Date'].apply (lambda date:pd.Period(date,freq='M'))
# Out:
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '27-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '20-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '13-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# ...

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region    Month
# 0  Albany  2015-12
# 1  Albany  2015-12
# 2  Albany  2015-12
# 3  Albany  2015-06
# ...

# %%
#Average monthly sales
avg_monthly_sales=df.groupby(df['Month'])['Total Volume'].mean()

# %%
avg_monthly_sales
# Out:
# Month
# 2015-01    1.984611e+06
# 2015-02    1.530926e+06
# 2015-03    1.867653e+06
# 2015-04    1.857106e+06
# 2015-05    2.025253e+06
# 2015-06    1.804561e+06
# 2015-07    1.756250e+06
# 2015-08    1.378348e+06
# 2015-09    1.070826e+06
# 2015-10    1.532913e+06
# 2015-11    1.096834e+06
# 2015-12    1.163282e+06
# 2016-01    1.580008e+06
# 2016-02    1.473113e+06
# 2016-03    1.598049e+06
# 2016-04    1.489546e+06
# 2016-05    1.868668e+06
# 2016-06    1.594725e+06
# 2016-07    2.217648e+06
# 2016-08    1.918387e+06
# 2016-09    1.500425e+06
# 2016-10    1.420263e+06
# 2016-11    1.044938e+06
# 2016-12    1.268990e+06
# Freq: M, Name: Total Volume, dtype: float64

# %%
sns.histplot(avg_monthly_sales)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Count'>

# %%
#Quaterly sales of avacado  in a year
df['Quater']=df['Date'].apply(lambda date:pd.Period(date,freq='Q'))
# Out:
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '27-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '20-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# C:\Users\Saurabh kumar\anaconda3\lib\site-packages\pandas\core\series.py:4433: UserWarning: Parsing '13-12-2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
# ...

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region    Month  Quater
# 0  Albany  2015-12  2015Q4
# 1  Albany  2015-12  2015Q4
# 2  Albany  2015-12  2015Q4
# ...

# %%
#Average qauterly sale
avg_Q_sales= df.groupby(df['Quater'])['Total Volume'].mean()

# %%
avg_Q_sales
# Out:
# Quater
# 2015Q1    1.829428e+06
# 2015Q2    1.906081e+06
# 2015Q3    1.384532e+06
# 2015Q4    1.229398e+06
# 2016Q1    1.556661e+06
# 2016Q2    1.643336e+06
# 2016Q3    1.926284e+06
# 2016Q4    1.241163e+06
# Freq: Q-DEC, Name: Total Volume, dtype: float64

# %%
sns.histplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Count'>

# %%
#Average sales of 4225
sns.histplot(df.groupby('region')['4225'].mean())
# Out:
# <AxesSubplot:xlabel='4225', ylabel='Count'>

# %%
#Average sales of 4770
sns.histplot(df.groupby('region')['4770'].mean())
# Out:
# <AxesSubplot:xlabel='4770', ylabel='Count'>

# %%
#Average price of 4046
sns.histplot(df.groupby('region')['4046'].mean())
# Out:
# <AxesSubplot:xlabel='4046', ylabel='Count'>

# %%
sns.pairplot(df)

# %%
df.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# 5  22-11-2015          1.26      55979.78  1184.27   48067.99   43.61
# 6  15-11-2015          0.99      83453.76  1368.92   73672.72   93.26
# 7  08-11-2015          0.98     109428.33   703.75  101815.36   80.00
# 8  01-11-2015          1.02      99811.42  1022.15   87315.57   85.34
# 9  25-10-2015          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# ...

# %%
y=df.drop(['Date','Quater','Month', 'Total Volume', '4046', '4225', '4770','Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year','region'], axis = 1)

# %%
y
# Out:
#       AveragePrice
# 0             1.33
# 1             1.35
# 2             0.93
# 3             1.08
# 4             1.28
# ...            ...
# 1512          1.39
# 1513          1.51
# 1514          1.48
# 1515          1.47
# 1516          1.43
#
# [1517 rows x 1 columns]

# %%
x=df.drop(['AveragePrice'],axis=1)

# %%
x
# Out:
#             Date  Total Volume      4046       4225      4770  Total Bags  \
# 0     27-12-2015      64236.62   1036.74   54454.85     48.16     8696.87
# 1     20-12-2015      54876.98    674.28   44638.81     58.33     9505.56
# 2     13-12-2015     118220.22    794.70  109149.67    130.50     8145.35
# 3     06-12-2015      78992.15   1132.00   71976.41     72.58     5811.16
# 4     29-11-2015      51039.60    941.48   43838.39     75.78     6183.95
# ...          ...           ...       ...        ...       ...         ...
# 1512  16-10-2016     190846.01  57529.11   56366.66  17531.78    59418.46
# 1513  09-10-2016     178235.75  43325.87   52189.61  19419.57    63300.70
# 1514  02-10-2016     178410.82  46364.75   52893.38  16736.92    62415.77
# 1515  25-09-2016     189131.52  54110.79   53593.58  17495.42    63931.73
# 1516  18-09-2016     182978.30  43116.41   54193.42  16563.91    69104.56
#
#       Small Bags  Large Bags  XLarge Bags          type  year     region  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=30)

# %%
x_train.shape
# Out:
# (1137, 14)

# %%
x_test.shape
# Out:
# (380, 14)

# %%
y_train.shape
# Out:
# (1137, 1)

# %%
y_test.shape
# Out:
# (380, 1)
